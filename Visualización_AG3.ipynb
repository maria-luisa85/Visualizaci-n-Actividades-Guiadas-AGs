# %% [markdown]
# <a href="https://colab.research.google.com/github/maria-luisa85/Visualizaci-n-Actividades-Guiadas-AGs/blob/master/Visualizaci%C3%B3n_AG3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nombre: María luisa Espada Durango
Url: https://vis-ag.stackblitz.io

# %%
#Importamos modulos
import pandas as pd
import io
import requests
import seaborn as sns
import timeit
import matplotlib.pyplot as plt

# %%
#Cargamos el data set de los pasajeros del Titanic
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
s=requests.get(url).content
titanic=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
#Renombra la columna class=clase y fare=tarifa
titanic.rename(columns={'class': 'clase'},
inplace=True)
titanic.rename(columns={'fare': 'tarifa'},
inplace=True)
#Muestra los valores distintos para class(clase)
titanic.clase.unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
#Primeras 5 filas
titanic.head(10)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
# 5         0       3    male   NaN  ...   NaN   Queenstown     no   True
# 6         0       1    male  54.0  ...     E  Southampton     no   True
# 7         0       3    male   2.0  ...   NaN  Southampton     no  False
# 8         1       3  female  27.0  ...   NaN  Southampton    yes  False
# 9         1       2  female  14.0  ...   NaN    Cherbourg    yes  False
#
# [10 rows x 15 columns]

# %%
#Añadimos nuevas columnas: is_old, is_baby
###############################################
def is_old_func(row):
  return row['age'] > 60
  
titanic['is_old'] = titanic.apply(is_old_func, axis='columns')

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  ...  deck  embark_town alive  alone is_old
# 0         0       3    male  22.0      1  ...   NaN  Southampton    no  False  False
# 1         1       1  female  38.0      1  ...     C    Cherbourg   yes  False  False
# 2         1       3  female  26.0      0  ...   NaN  Southampton   yes   True  False
# 3         1       1  female  35.0      1  ...     C  Southampton   yes  False  False
# 4         0       3    male  35.0      0  ...   NaN  Southampton    no   True  False
# 5         0       3    male   NaN      0  ...   NaN   Queenstown    no   True  False
# 6         0       1    male  54.0      0  ...     E  Southampton    no   True  False
# 7         0       3    male   2.0      3  ...   NaN  Southampton    no  False  False
# 8         1       3  female  27.0      0  ...   NaN  Southampton   yes  False  False
# 9         1       2  female  14.0      1  ...   NaN    Cherbourg   yes  False  False
#
# [10 rows x 16 columns]

# %%
#Otra forma de definir una nueva columna
titanic.eval ( ' is_baby = age< 15 ' , inplace = True)

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  ...  alive  alone  is_old is_baby
# 0         0       3    male  22.0  ...     no  False   False   False
# 1         1       1  female  38.0  ...    yes  False   False   False
# 2         1       3  female  26.0  ...    yes   True   False   False
# 3         1       1  female  35.0  ...    yes  False   False   False
# 4         0       3    male  35.0  ...     no   True   False   False
# 5         0       3    male   NaN  ...     no   True   False   False
# 6         0       1    male  54.0  ...     no   True   False   False
# 7         0       3    male   2.0  ...     no  False   False    True
# 8         1       3  female  27.0  ...    yes  False   False   False
# 9         1       2  female  14.0  ...    yes  False   False    True
#
# [10 rows x 17 columns]

# %%
#Consulta con condiciones
titanic[(titanic.sex == 'female')& (titanic['clase'].isin(['First', 'Third']))& (titanic.age > 25 )& (titanic.survived == 0)]
# Out:
#      survived  pclass     sex   age  ...  alive  alone  is_old is_baby
# 18          0       3  female  31.0  ...     no  False   False   False
# 40          0       3  female  40.0  ...     no  False   False   False
# 100         0       3  female  28.0  ...     no   True   False   False
# 132         0       3  female  47.0  ...     no  False   False   False
# 167         0       3  female  45.0  ...     no  False   False   False
# 177         0       1  female  50.0  ...     no   True   False   False
# 251         0       3  female  29.0  ...     no  False   False   False
# 254         0       3  female  41.0  ...     no  False   False   False
# 276         0       3  female  45.0  ...     no   True   False   False
# 362         0       3  female  45.0  ...     no  False   False   False
# 396         0       3  female  31.0  ...     no   True   False   False
# 423         0       3  female  28.0  ...     no  False   False   False
# 503         0       3  female  37.0  ...     no   True   False   False
# 534         0       3  female  30.0  ...     no   True   False   False
# 567         0       3  female  29.0  ...     no  False   False   False
# 610         0       3  female  39.0  ...     no  False   False   False
# 617         0       3  female  26.0  ...     no  False   False   False
# 638         0       3  female  41.0  ...     no  False   False   False
# 657         0       3  female  32.0  ...     no  False   False   False
# 678         0       3  female  43.0  ...     no  False   False   False
# 736         0       3  female  48.0  ...     no  False   False   False
# 767         0       3  female  30.5  ...     no   True   False   False
# 799         0       3  female  30.0  ...     no  False   False   False
# 885         0       3  female  39.0  ...     no  False   False   False
#
# [24 rows x 17 columns]

# %%
#Distribución de las clases.Gráfico de columnas.
sns.countplot(x="pclass", data=titanic)

# %%
#Histograma
#Distribución de la edad(ege)
sns.distplot(titanic.age.dropna( ))
plt.show( )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#BoxPlot de la edad por sexo y clase
with sns.axes_style(style='ticks'):
  ax = sns.catplot("sex", "age", "pclass" ,
data=titanic, kind="box")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Diagrama de puntos para tarifa y edad
#Distribución cruzada de Edad y Tarifa
sns.jointplot(x='tarifa',y='age',data=titanic)

# %%
#Distribución de la edad según la categorías: survived, clase
#Cambiamos el font
sns.set(font_scale=1)
g = sns.FacetGrid(titanic, row='survived',
col='pclass')
g.map(sns.distplot, "age")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Mapa de calor de correlaciones
tc = titanic.corr()
sns.heatmap(tc,cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
#Diagramas de dispersión de parejas de variables cuantitativas
#Define un subconjuto de datos con las variablesnuméricas
titanic_num =titanic[['survived','pclass','sibsp','parch','tarifa']]
#Hace una matriz de diagramas de dispersión de parejas de variables.
sns.pairplot(titanic_num, hue="survived")
plt.show()

# %%
#Distribución de clase/edad y supervivientes.
sns.set(font_scale=1)
f = sns.FacetGrid(titanic, row='sex',col='pclass',hue='survived')
f.map(sns.histplot,"age")
plt.show()
